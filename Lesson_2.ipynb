# %% [markdown]
# <a href="https://colab.research.google.com/github/lassenilssonnn/digital-legal-studies-python/blob/main/Lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to lesson 2 of Computational Legal Science!
#
#
#
#
# ## Submitting Notebooks
#
# Remember, you need to submit these notebooks, which you do through moodle.
# Steps:
#
# 1. Access the notebook on Moodle ✅
# 2. Complete the exercises in the notebook (you have time for this in class)
# 3. Save the notebook under file, print, save as PDF (which you can choose under destination, if it isn't the default). Save it with your name.
# 4. Upload it to moodle as a PDF under the correct notebook name.
#
# ## What we'll be learning today
#
# Today we'll be re-capping what we learned last time, learn about functions, methods, and modules. We'll also finally do some minor computational law. Strap in!

# %% [markdown]
# # QUICK RECAP
#
#
# ## Python
#
# Python is a programming language. It's named after Monty Python, not the snake. It is the most widely used programming language--and for good reason. It is humanlike in its language and has extensive libraries.
#
# Usually, you'd need to install a program, but we can run it in these cells, clicking either the arrow in the top left of the cells, or by holding shift+enter.
#
# Like a language, there are certain syntactic (grammar) rules we must follow for the Python to understand what we are telling it. These are fairly simple. We read and write the language like we would any other, from left to right, from top to bottom.
#
# ```
# print(my_variable)
#
# my_variable = "This isn't gonna work, is it?"
# ```
# This for example-- to those of you that remember printing and variables-- will not work. Python has not yet seen what our variable is, yet we are asking it to print it. This will give us an error. We'll talk more about them some other time.
#
# ### Will I ever learn this stuff?
#
# Yes! Python is much easier to learn than most languages-- there really aren't that many rules, and the logic is pretty simple, but there are layers to this stuff. We can do almost everything we need at the surface (we are not coding a rocket ship).
#
# Instead of trying to write code as fancy as English is written in Shakespeare's King Lear, we can do with the Very Hungry Caterpillar-esque Python.
#
#
#
#
# ## Python fundamentals -- Variables and data types.
#
# In Python, one of our main tools is the variable.
#
# Variables are containers that contain 'values' (data). If we want to work with something, we need to put it in a container.
#
#
# ```
# my_first_variable = "Hello"
# ```
#
# I have now stored the sentence "Hello" in a variable by using the equals sign, which is the way we assign variables values. We can store all kinds of stuff. We could store every decision made by the European Court of Human Rights in a variable. We could store the words we'll use to search them.
#
# If I were to simply write
#
#
#
#
# ```
# "Hello"
# ```
# or
#
# ```
# my_first_variable
# ```
#
# We would get an error. We have values (data) floating around without being stored anywhere. That's not proper Python grammar.
#
# **For code to run in Python, It must DO SOMETHING.**
#
# We call code that does something statements. A statement can be very simple. Assigning a variable is a statement, it's code that does something according to the grammar of Python.
#
# Unlike a Notebook where we can scribble whatever, we must DO something, and do so according to the rules of the program.
#
#
# ```
# my_second_variable = 28
# ```
# This is a statement. It assigns a variable with the value 28. The value 28 is a data type--almost everything in Python is. This one is an integer an (INT).
#
# These are usually very intuitive. But, we can get errors if we use different data types incorrectly.
#
# ```
# example_of_text = "We call this data type strings"
#
# example_of_number = 28
#
# answer_to_calculation = example_of_text / example_of_number
# ```
#
# This gives us an error. -- Why?
#
#
# ### Good Python Practice
#
# We can call our variables anything we want. But we don't. We write them with lowercase and we try to make them comprehensible. If we write multiple words in one variable, we seperate them with lowercase (if we used space, Python wouldn't know that it's a variable, and would give us an error).
#
#
# ```
# a = 28
# b = "Copenhagen"
# c = "Ate too much cake"
#
# age = 28
# hospital_area = "Copenhagen"
# reason_for_visit = "Ate too much cake"
# ```
#
# That's a lot more informative. Another thing we do is leave us helpful notes. Using the # symbol, Python ignores it as 'code' and allows us to write things to ourselves and to others.
#
#
#
# ```
# #DON'T CHANGE THIS VARIABLE (THE PROGRAM WILL NOT WORK)
# answer_to_life = 42
# ```
# Good to know.

# %% [markdown]
# # TODAY'S LESSON:
#
# ## Functions, methods, and modules... And some visual magic.
#
#
# ### Functions
#
# A function is like a mini program within a program. It is a block of code, meaning some code that belongs together, that only runs, when it is called. We make functions to re-use code.  We have already seen some when we used print() and type().
#
# You can tell something is a function by the parentheses. To understand functions, let's try to make one:

# %%
def my_first_function():
  print("This is my first function!")
  print("Wait, we are using a function in a function?")

my_first_function() # To see it in action, we need to use it, like we would the print() function. We CALL it.
# Out:
# This is my first function!
# Wait, we are using a function in a function?

# %% [markdown]
# A function first needs to be defined. We define a function like this:
#   `def name():`
#
# We are then ready to say what it should do, to write our "mini-program"-- the body of our function. To tell Python that the code belongs together, we use **indentation**.
#
# Idendations is how we create hierarchy in code.
#
# ```
# def function_to_show_indentation():
#   indented_variable = "See how there's space in front of this variable's name?"
#
# other_code_in_my_program = "this doesn't belong with the function"
# ```
#
# def function_to_show_indentation(): and other_code_in_my_program are in the same hierarchy; they are independent of one another. indented_variable is under the function.
#
# Anything indented usually only exists only in that block.
#
#
#
# ```
# print(indented_variable)
# ```
# this would say indented_variable not defined. I could print(other_code_in_my_program), because that is not in that indented block.
#
# What's the point if it only exists there? Well, we can use them in the function as we'll see.

# %% [markdown]
# # TASK TIME! CREATE YOUR FIRST FUNCTION
#
# I want you to make your own function which, when called, prints some text ("string") that says "I did it". To print something, you'll need to use the print() function. -- With some text in it.
#
# Remember you need to:
#
#
# 1.   Define your function, you can call it whatever (use similar logic to naming variables)
# 2.   Write the body of the function. It should print a string.
# 3.   Once you've defined it. Remember to call it.

# %%
# DON'T MAKE YOUR FUNCTION HERE-- THIS IS MY FUNCTION. I made it to help you.

def this_is_your_professors_function():
  print("Make your own function, which, when ran, prints 'I did it'")

this_is_your_professors_function()
# Out:
# Make your own function, which, when ran, prints 'I did it'

# %%
# MAKE YOUR FUNCTION HERE AND RUN IT (YOU RUN IT BY PRESSING -> ON THE TOP LEFT, OR SHIFT+ENTER)

# %% [markdown]
# We can take functions further by giving them variables.
#
# To give a function a variable, we put it between the () when we define it.
#
#
#
#
# ```
# def function_with_variable(x):
#   x = x**2
#   print(x)
# ```
#
# X is simply a stand-in, it means we can put a variable in there, and in the block that variable is then referred to as X.
#
# Here the function will, if entered with a variable (which must be an integer since we do a mathematical operation) tell us that variables exponent by first saving it in a variable and then printing it.
#
# We can, by the way, do mathematical operations in Python by using what we call operands (operators).
#
# ```
# sum1 = 100 + 50      # 150 (100 + 50)
# sum2 = sum1 + 250    # 400 (150 + 250)
# sum3 = sum2 + sum2   # 800 (400 + 400)
# ```
#
# We will use them a lot, most often not related to numbers... More next time.

# %%
## Here is an example of our function actually called in a coding cell.

def function_with_variable(x):
  x = x**2
  print(x)

i_want_exponent_of_this = 28

function_with_variable(28)
# Out:
# 784

# %% [markdown]
# # Why use functions?
#
# We often need to do the same thing over and over again, or people do, which means we re-use code--Either our own, or someone else's. For example, we use Python's print() function all the time. That is someone having done the same thing we did: defining their function, writing the body of it.
#
# `def print(x): A lot of complicated code someone wrote for us`
#
#
# Print is fundamental, but people have defined a lot of functions; they have made a lot of 'mini-programs' that we can use-- just like we use the print function.
#
# # Modules
#
# Modules are other people's python programs. They are written like ours, but uploaded somewhere where we can import them. The most popular ones are already sort-of installed in Python, but we need to 'import' them into our program, so that it knows we are using it.
#
#
# ```
# import math
# ```
#
# We import modules by using Python's keyword "import".
#
# There is a Module called math (someone wrote a Python program and made a bunch of functions that do complicated math stuff and made it available to us), which we have imported, and can now use.
#
# But, first we need to know how to use it-- someone else made it, I don't know what their functions need, or even what they're called or do.
#
# **Documentation** is the key here. Documentation is what we call the files and websites where people write what their modules (programs) do and how to use them.
#
# [The Math Modules Documentation](https://docs.python.org/3/library/math.html).
#
# By looking at this, I can figure out how to easily get the exponent without writing any functions of my own. Smart.

# %% [markdown]
# ![Screenshot 2026-02-17 at 13.35.18.png](data:image/png;base64,...)

# %% [markdown]
# We can see that the function we want is called pow and takes two variables, the number that needs to be raised to the power, and the power. We already have our variable that contains our number.
#
# ```
# i_want_exponent_of_this = 28
# ```
# And we know we want ^2.
# Let's try to use the function.

# %% [markdown]
# To use modules, we must 'access' them. First we import it, and then we use it. For Python to know we are gonna use the math module's function, we tell it by either accessing it like this (so it knows pow is from math)
#
# ```
# math.pow()
# ```
#
# Or by importing it in a way so that Python knows that function is from the math
#
# ```
# from math import pow
# ```
#
# If we import it like that we don't need to first 'access' math. It's quite clear that pow is from math. But I think it makes it clearer when we use module.function() as it makes it clearer where our code comes from.

# %%
import math

i_want_exponent_of_this = 28

math.pow(i_want_exponent_of_this, 2) #remember it takes two variables
# Out:
# 784.0

# %% [markdown]
# Voilá! By using someone elses code, we've been able to find the exponent, granted, that isn't super difficult, but I hope you see the trick. We can steal as much as we want, be super lazy, and easily do cool things.
#
#
# ## TASK TIME
#
# Now, I want you to consult the documentation from the math module to figure out how to use one of its functions to calculate a squareroot. I want you, in the cell below, to calculate the squareroot of this fine variable I've made for you.
#
# ```
# variable_to_squareroot = 42
# ```
# This would be the same as simply calculating the squareroot of 42, but let's use variables.
#
# [Python Math Module Documentation](https://docs.python.org/3/library/math.html). Look for a function that gives you the squareroot.
#
# I've already imported the math module for you, you just need to 'access' it and use the right function name.

# %%
##write your answer in this cell, you should use a function from the math module to calculate the square root of the variable, which is 42
#once you've found the function, written it and fed it the variable, remember to run the cell.

import math

variable_to_squareroot = 42


#You did it right if it prints 6.48074069840786

# %% [markdown]
# # METHODS
#
# Methods are the cousins of functions.
#
# In Python, a method is a function associated with a particular data type.
#
# We've already seen the data types INT, STR, FLOAT, LIST.
#
# But in Python you can actually also create NEW data types (we won't really be needing to do this, but we could).
#
# To create new data types, we make classes-- let's not worry about that-- but when we make data types, we can create functions connected to them. **THESE ARE METHODS.**
#
# So, we are not making any new data types and giving them functions, BUT we are using data types (INT, STR, FLOAT, LIST, ETC.) that already have functions (methods) in them!
#
# Different data types have different methods associated with them. Let's look at some methods for the data type STR (Strings, i.e., normal text).
#
# ```
# capitalize()	Converts the first character to upper case
# lower()	Converts a string into lower case
# join()	Converts the elements of an iterable into a string
# ```
#
# To use them we write them after the data type with a "." and then the method, and we call it just like we would a function. Remember the () at the end!
#
# ```
# my_string = "hi".capitalize()
# ```

# %%
capitalized_text = "hello".capitalize()

print(capitalized_text)

# I could also just print("hello".capitalize()) which capitalizes it without saving it. You can have methods within functions

print("see?".capitalize())
# Out:
# Hello
# See?

# %% [markdown]
# # PUTTING IT TOGETHER!
#
# Making a word cloud.

# %%
from collections import Counter

text = """
Whereas recognition of the inherent dignity and of the equal and inalienable rights of all members of the human family is the foundation of freedom, justice and peace in the world,
Whereas disregard and contempt for human rights have resulted in barbarous acts which have outraged the conscience of mankind, and the advent of a world in which human beings shall enjoy freedom of speech and belief and freedom from fear and want has been proclaimed as the highest aspiration of the common people,
Whereas it is essential, if man is not to be compelled to have recourse, as a last resort, to rebellion against tyranny and oppression, that human rights should be protected by the rule of law,
Whereas it is essential to promote the development of friendly relations between nations,
Whereas the peoples of the United Nations have in the Charter reaffirmed their faith in fundamental human rights, in the dignity and worth of the human person and in the equal rights of men and women and have determined to promote social progress and better standards of life in larger freedom,
Whereas Member States have pledged themselves to achieve, in co-operation with the United Nations, the promotion of universal respect for and observance of human rights and fundamental freedoms,
Whereas a common understanding of these rights and freedoms is of the greatest importance for the full realization of this pledge,
Now, therefore,
The General Assembly,
Proclaims this Universal Declaration of Human Rights as a common standard of achievement for all peoples and all nations, to the end that every individual and every organ of society, keeping this Declaration constantly in mind, shall strive by teaching and education to promote respect for these rights and freedoms and by progressive measures, national and international, to secure their universal and effective recognition and observance, both among the peoples of Member States themselves and among the peoples of territories under their jurisdiction.
"""



#Stop words are what we call those common, boring words that don't tell us a whole lot.

#Try to add or remove stop words here. Removal might not work, unless you 'restart' as it remembers.

stop_words = [
   "the", "and", "to", "of", "for", "is", "in", "that", "if", "or",
  "has", "have", "be", "only", "one", "more", "with", "as", "by", "in"]

#Look at the word cloud, and see if we need more stop-words.
#Some ideas...: "whereas", "their", "a"

# %%
words_from_text = text.lower().split()

clean_words = []

for word in words_from_text:
  if word not in stop_words:
    clean_words.append(word)

print(f"This is how many words are in the 'cleaned' version: {len(clean_words)}")


frequency_of_words = Counter(clean_words)
# Out:
# This is how many words are in the 'cleaned' version: 196

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=1000, height=600, background_color="white")
wordcloud.generate_from_frequencies(frequency_of_words)

plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(999.5), np.float64(599.5), np.float64(-0.5))
