# %% [markdown]
# <a href="https://colab.research.google.com/github/lassenilssonnn/digital-legal-studies-python/blob/main/intro_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello and welcome to the first notebook!
#
# ## This is the environment we'll be working in. We can write code directly in these cells. 🐱

# %%
# When code is written like this with a hashtag infront of it; it doesn't register, and I'll use this to leave you helpful notes.

# %%
When code isn't written keep this in mind, we have problems.
# Out:
#   File "/tmp/ipython-input-1432176356.py", line 1
#     When code isn't written keep this in mind, we have problems.
#                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# To write code, we must write in a language the machine understands! The programs work with various functions and variables.

# %%
this_is_a_variable = "What we are storing in the variable X, is a string. It is text information. I.E literally this"
another_variable = 14 #This is an int, meaning an integer.
we_can_call_variables_anything = 14.2 # this is a float, meaning it has a 'floating point, i.e. a decimal point

# We use print statements to 'print' our results
print(this_is_a_variable)

our_variables = [this_is_a_variable, another_variable, we_can_call_variables_anything]

# what
# Out:
# What we are storing in the variable X, is a string. It is text information. I.E literally this

# %%
print()
